# %%
import cv2
# cv2.xfeatures2d.SIFT_create()

# %%
path_img_1 = r'/home/anton/KTH/year5/5LSH0/Weekly Assignments/4_SIFT&RANSAC/all_souls_000002.jpg'
path_img_2 = r'/home/anton/KTH/year5/5LSH0/Weekly Assignments/4_SIFT&RANSAC/all_souls_000006.jpg'
path_img_3 = r'/home/anton/KTH/year5/5LSH0/Weekly Assignments/4_SIFT&RANSAC/all_souls_000013.jpg'

img_1 = cv2.imread(path_img_1)
# img_2 = cv2.imread(path_img_2)
# img_3 = cv2.imread(path_img_3)

cv2.imshow("img_1", img_1)
# cv2.imshow("img_2", img_2)
# cv2.imshow("img_3", img_3)
  
#waits for user to press any key 
#(this is necessary to avoid Python kernel form crashing)
cv2.waitKey(0) 
  
#closing all open windows 
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x1449070) is not the object's thread (0x17c8df0).
# Cannot move to target thread (0x1449070)
#
# QObject::moveToThread: Current thread (0x1449070) is not the object's thread (0x17c8df0).
# Cannot move to target thread (0x1449070)
#
# QObject::moveToThread: Current thread (0x1449070) is not the object's thread (0x17c8df0).
# Cannot move to target thread (0x1449070)
#
# QObject::moveToThread: Current thread (0x1449070) is not the object's thread (0x17c8df0).
# Cannot move to target thread (0x1449070)
#
# QObject::moveToThread: Current thread (0x1449070) is not the object's thread (0x17c8df0).
# Cannot move to target thread (0x1449070)
#
# QObject::moveToThread: Current thread (0x1449070) is not the object's thread (0x17c8df0).
# Cannot move to target thread (0x1449070)
#
# QObject::moveToThread: Current thread (0x1449070) is not the object's thread (0x17c8df0).
# Cannot move to target thread (0x1449070)
#
# ...
