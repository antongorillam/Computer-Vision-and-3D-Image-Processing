# %%
import torch
import torch.nn as nn
import matplotlib
from dataloader import DataLoader

# %%
IMG_DIM = 28
MNIST_PATH = r"../mnist/"
EPOCHS = 200
BATCH_SIZE = 500
LEARNING_RATE = 1e-3
MOMENTUM = 5e-2
WEIGHT_DECAY = 1e-5
NOISE_BOUND = 0.3
CORRUPT_DATA = None

# %%
class Autoencoder(nn.Module):
    def __init__(self):
        super().__init__()

        self.encoder = nn.Sequential(
            nn.Linear(IMG_DIM * IMG_DIM, 512),
            nn.ReLU(),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
        )

        self.decoder = nn.Sequential(
            nn.Linear(16, 32),
            nn.ReLU(),
            nn.Linear(32, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128, 256),
            nn.ReLU(),
            nn.Linear(256, 512),
            nn.ReLU(),
            nn.Linear(512, IMG_DIM * IMG_DIM),
            nn.Sigmoid()
        )
    
    def forward(self, x):
        encoded = self.encoder(x) 
        decoded = self.decoder(encoded)
        return decoded

# %%
from torch.utils.tensorboard import SummaryWriter
from torch import optim
import time

model = Autoencoder()
criterion = nn.MSELoss() 
optimizer = optim.Adam(
    model.parameters(),
    lr=LEARNING_RATE,
    weight_decay=WEIGHT_DECAY,
    # momentum=MOMENTUM,
)
print(model.train())
# Out:
# Autoencoder(
#   (encoder): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=128, out_features=64, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=64, out_features=32, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=32, out_features=16, bias=True)
#     (11): ReLU()
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=16, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=128, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=128, out_features=256, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=256, out_features=512, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=512, out_features=784, bias=True)
#     (11): Sigmoid()
#   )
# )

# %%
writer = SummaryWriter("runs/complex_ae")

def train(train_loader, val_loader, epochs):
    

    tic = time.perf_counter()

    for epoch in range(1, epochs+1):
        train_loss = 0
        num_samples = 0
        for _, (image, _) in enumerate(train_loader):
            image = image.reshape(-1, IMG_DIM * IMG_DIM)            
            reconstructed_image = model(image)
            loss = criterion(reconstructed_image, image)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            train_loss += loss.item()
            num_samples += image.size(0) 

        toc = time.perf_counter()
        time_format = time.strftime("%M:%S", time.gmtime(toc - tic))
        
        train_loss = train_loss / num_samples
        _, _, val_loss = evaluate_batch(val_loader)
        
        print(f"Time elapsed: {time_format}, epoch: {str(epoch).zfill(2)}/{epochs}, train_loss: {train_loss*100:.5f}, val_loss: {val_loss*100:.5f}")
        writer.add_scalar("train_mse_loss", train_loss, epoch)
        writer.add_scalar("val_mse_loss", val_loss, epoch)
        writer.add_images("original_image", image.reshape(-1, IMG_DIM, IMG_DIM)[0], epoch, dataformats="HW")
        writer.add_images("reconstructed_image", reconstructed_image.reshape(-1, IMG_DIM, IMG_DIM)[0], epoch, dataformats="HW")

def evaluate_batch(data_loader):
    with torch.no_grad():
        tot_loss = 0
        num_samples = 0
        for _, (images, label) in enumerate(data_loader):
            images = images.reshape(-1, IMG_DIM * IMG_DIM)            
            reconstructed_image = model(images)
            tot_loss += criterion(reconstructed_image, images).item()
            num_samples += images.size(0)
        loss = tot_loss / num_samples
    return images, reconstructed_image, loss

def evaluate_image(data_loader):
    with torch.no_grad():
        out = []
        for _, (images, labels) in enumerate(data_loader):
            for image, label in zip(images, labels):
                image = image.reshape(1, IMG_DIM*IMG_DIM)
                reconstructed_image = model(image)
                loss = criterion(reconstructed_image, image).item()
                out.append((image.numpy(), reconstructed_image.numpy(), loss, label.item()))
    return out

def predict(data_loader, threshold):
    out = evaluate_image(data_loader)
    labels = [element[3] for element in out]
    preds = [int(element[2] < threshold) for element in out]
    return preds, labels

# %%
dl = DataLoader()
dl.prepareMNIST(mnist_path=MNIST_PATH, num_train_data=5000, num_normal_data=100, num_anomaly_data=100, corrupt_train=CORRUPT_DATA, noise_bound=NOISE_BOUND)
train_loader, val_loader, normal_loader, anomaly_loader = dl.getDataLoaderMNIST(batch_size=BATCH_SIZE)

# %%
train(train_loader, val_loader, epochs=EPOCHS)
writer.flush()
# Out:
# Time elapsed: 00:00, epoch: 01/200, train_loss: 0.04224, val_loss: 0.07773
# Time elapsed: 00:01, epoch: 02/200, train_loss: 0.02199, val_loss: 0.05362
# Time elapsed: 00:01, epoch: 03/200, train_loss: 0.01471, val_loss: 0.05082
# Time elapsed: 00:02, epoch: 04/200, train_loss: 0.01405, val_loss: 0.04969
# Time elapsed: 00:02, epoch: 05/200, train_loss: 0.01371, val_loss: 0.04813
# Time elapsed: 00:03, epoch: 06/200, train_loss: 0.01355, val_loss: 0.04759
# Time elapsed: 00:03, epoch: 07/200, train_loss: 0.01350, val_loss: 0.04736
# Time elapsed: 00:04, epoch: 08/200, train_loss: 0.01347, val_loss: 0.04744
# Time elapsed: 00:04, epoch: 09/200, train_loss: 0.01345, val_loss: 0.04740
# Time elapsed: 00:05, epoch: 10/200, train_loss: 0.01344, val_loss: 0.04749
# Time elapsed: 00:05, epoch: 11/200, train_loss: 0.01340, val_loss: 0.04664
# Time elapsed: 00:06, epoch: 12/200, train_loss: 0.01316, val_loss: 0.04541
# Time elapsed: 00:06, epoch: 13/200, train_loss: 0.01292, val_loss: 0.04466
# Time elapsed: 00:07, epoch: 14/200, train_loss: 0.01250, val_loss: 0.04524
# Time elapsed: 00:07, epoch: 15/200, train_loss: 0.01221, val_loss: 0.04431
# Time elapsed: 00:08, epoch: 16/200, train_loss: 0.01209, val_loss: 0.04398
# Time elapsed: 00:09, epoch: 17/200, train_loss: 0.01197, val_loss: 0.04376
# Time elapsed: 00:09, epoch: 18/200, train_loss: 0.01183, val_loss: 0.04371
# Time elapsed: 00:10, epoch: 19/200, train_loss: 0.01172, val_loss: 0.04343
# Time elapsed: 00:10, epoch: 20/200, train_loss: 0.01165, val_loss: 0.04310
# Time elapsed: 00:11, epoch: 21/200, train_loss: 0.01159, val_loss: 0.04326
# Time elapsed: 00:11, epoch: 22/200, train_loss: 0.01153, val_loss: 0.04336
# Time elapsed: 00:12, epoch: 23/200, train_loss: 0.01148, val_loss: 0.04320
# Time elapsed: 00:12, epoch: 24/200, train_loss: 0.01142, val_loss: 0.04319
# Time elapsed: 00:13, epoch: 25/200, train_loss: 0.01135, val_loss: 0.04307
# Time elapsed: 00:13, epoch: 26/200, train_loss: 0.01130, val_loss: 0.04307
# Time elapsed: 00:14, epoch: 27/200, train_loss: 0.01122, val_loss: 0.04287
# Time elapsed: 00:14, epoch: 28/200, train_loss: 0.01117, val_loss: 0.04272
# Time elapsed: 00:15, epoch: 29/200, train_loss: 0.01108, val_loss: 0.04259
# Time elapsed: 00:15, epoch: 30/200, train_loss: 0.01096, val_loss: 0.04228
# Time elapsed: 00:16, epoch: 31/200, train_loss: 0.01087, val_loss: 0.04268
# Time elapsed: 00:16, epoch: 32/200, train_loss: 0.01079, val_loss: 0.04203
# Time elapsed: 00:17, epoch: 33/200, train_loss: 0.01067, val_loss: 0.04203
# Time elapsed: 00:17, epoch: 34/200, train_loss: 0.01057, val_loss: 0.04184
# Time elapsed: 00:18, epoch: 35/200, train_loss: 0.01046, val_loss: 0.04092
# Time elapsed: 00:18, epoch: 36/200, train_loss: 0.01035, val_loss: 0.04099
# Time elapsed: 00:19, epoch: 37/200, train_loss: 0.01024, val_loss: 0.04107
# Time elapsed: 00:19, epoch: 38/200, train_loss: 0.01016, val_loss: 0.04085
# Time elapsed: 00:20, epoch: 39/200, train_loss: 0.01003, val_loss: 0.04068
# Time elapsed: 00:21, epoch: 40/200, train_loss: 0.00993, val_loss: 0.04084
# Time elapsed: 00:21, epoch: 41/200, train_loss: 0.00989, val_loss: 0.04074
# Time elapsed: 00:22, epoch: 42/200, train_loss: 0.00981, val_loss: 0.04049
# Time elapsed: 00:22, epoch: 43/200, train_loss: 0.00973, val_loss: 0.04040
# Time elapsed: 00:23, epoch: 44/200, train_loss: 0.00969, val_loss: 0.04058
# Time elapsed: 00:24, epoch: 45/200, train_loss: 0.00962, val_loss: 0.04026
# Time elapsed: 00:25, epoch: 46/200, train_loss: 0.00954, val_loss: 0.04034
# Time elapsed: 00:25, epoch: 47/200, train_loss: 0.00950, val_loss: 0.04004
# Time elapsed: 00:26, epoch: 48/200, train_loss: 0.00947, val_loss: 0.04013
# Time elapsed: 00:27, epoch: 49/200, train_loss: 0.00939, val_loss: 0.04014
# Time elapsed: 00:27, epoch: 50/200, train_loss: 0.00935, val_loss: 0.04020
# Time elapsed: 00:28, epoch: 51/200, train_loss: 0.00931, val_loss: 0.04003
# Time elapsed: 00:28, epoch: 52/200, train_loss: 0.00931, val_loss: 0.03977
# Time elapsed: 00:29, epoch: 53/200, train_loss: 0.00923, val_loss: 0.03992
# Time elapsed: 00:29, epoch: 54/200, train_loss: 0.00920, val_loss: 0.04000
# Time elapsed: 00:30, epoch: 55/200, train_loss: 0.00915, val_loss: 0.03980
# Time elapsed: 00:30, epoch: 56/200, train_loss: 0.00908, val_loss: 0.04025
# Time elapsed: 00:31, epoch: 57/200, train_loss: 0.00906, val_loss: 0.04027
# Time elapsed: 00:31, epoch: 58/200, train_loss: 0.00907, val_loss: 0.03992
# Time elapsed: 00:32, epoch: 59/200, train_loss: 0.00901, val_loss: 0.03999
# Time elapsed: 00:32, epoch: 60/200, train_loss: 0.00895, val_loss: 0.04010
# Time elapsed: 00:33, epoch: 61/200, train_loss: 0.00893, val_loss: 0.03978
# Time elapsed: 00:33, epoch: 62/200, train_loss: 0.00890, val_loss: 0.03967
# Time elapsed: 00:34, epoch: 63/200, train_loss: 0.00888, val_loss: 0.03963
# Time elapsed: 00:34, epoch: 64/200, train_loss: 0.00883, val_loss: 0.04001
# Time elapsed: 00:35, epoch: 65/200, train_loss: 0.00879, val_loss: 0.03992
# Time elapsed: 00:35, epoch: 66/200, train_loss: 0.00883, val_loss: 0.03981
# Time elapsed: 00:36, epoch: 67/200, train_loss: 0.00880, val_loss: 0.03985
# Time elapsed: 00:36, epoch: 68/200, train_loss: 0.00873, val_loss: 0.04062
# Time elapsed: 00:37, epoch: 69/200, train_loss: 0.00870, val_loss: 0.04012
# Time elapsed: 00:37, epoch: 70/200, train_loss: 0.00862, val_loss: 0.04010
# Time elapsed: 00:38, epoch: 71/200, train_loss: 0.00859, val_loss: 0.03996
# Time elapsed: 00:38, epoch: 72/200, train_loss: 0.00857, val_loss: 0.03982
# Time elapsed: 00:39, epoch: 73/200, train_loss: 0.00852, val_loss: 0.04004
# Time elapsed: 00:40, epoch: 74/200, train_loss: 0.00854, val_loss: 0.04004
# Time elapsed: 00:40, epoch: 75/200, train_loss: 0.00848, val_loss: 0.03980
# Time elapsed: 00:41, epoch: 76/200, train_loss: 0.00855, val_loss: 0.04041
# Time elapsed: 00:41, epoch: 77/200, train_loss: 0.00852, val_loss: 0.04020
# Time elapsed: 00:42, epoch: 78/200, train_loss: 0.00846, val_loss: 0.03999
# Time elapsed: 00:42, epoch: 79/200, train_loss: 0.00842, val_loss: 0.03999
# Time elapsed: 00:43, epoch: 80/200, train_loss: 0.00838, val_loss: 0.03994
# Time elapsed: 00:43, epoch: 81/200, train_loss: 0.00839, val_loss: 0.03985
# Time elapsed: 00:44, epoch: 82/200, train_loss: 0.00836, val_loss: 0.03967
# Time elapsed: 00:44, epoch: 83/200, train_loss: 0.00837, val_loss: 0.04003
# Time elapsed: 00:45, epoch: 84/200, train_loss: 0.00832, val_loss: 0.04034
# Time elapsed: 00:45, epoch: 85/200, train_loss: 0.00832, val_loss: 0.03992
# Time elapsed: 00:46, epoch: 86/200, train_loss: 0.00827, val_loss: 0.03996
# Time elapsed: 00:46, epoch: 87/200, train_loss: 0.00826, val_loss: 0.03990
# Time elapsed: 00:47, epoch: 88/200, train_loss: 0.00824, val_loss: 0.03997
# Time elapsed: 00:47, epoch: 89/200, train_loss: 0.00827, val_loss: 0.04000
# Time elapsed: 00:48, epoch: 90/200, train_loss: 0.00825, val_loss: 0.03987
# Time elapsed: 00:48, epoch: 91/200, train_loss: 0.00823, val_loss: 0.03982
# Time elapsed: 00:49, epoch: 92/200, train_loss: 0.00822, val_loss: 0.03986
# Time elapsed: 00:50, epoch: 93/200, train_loss: 0.00817, val_loss: 0.04008
# Time elapsed: 00:50, epoch: 94/200, train_loss: 0.00813, val_loss: 0.04022
# Time elapsed: 00:51, epoch: 95/200, train_loss: 0.00812, val_loss: 0.04025
# Time elapsed: 00:52, epoch: 96/200, train_loss: 0.00812, val_loss: 0.04024
# Time elapsed: 00:52, epoch: 97/200, train_loss: 0.00809, val_loss: 0.04007
# Time elapsed: 00:53, epoch: 98/200, train_loss: 0.00808, val_loss: 0.04027
# Time elapsed: 00:54, epoch: 99/200, train_loss: 0.00814, val_loss: 0.04006
# Time elapsed: 00:54, epoch: 100/200, train_loss: 0.00814, val_loss: 0.04007
# Time elapsed: 00:55, epoch: 101/200, train_loss: 0.00808, val_loss: 0.03997
# Time elapsed: 00:56, epoch: 102/200, train_loss: 0.00807, val_loss: 0.03993
# Time elapsed: 00:56, epoch: 103/200, train_loss: 0.00805, val_loss: 0.04008
# Time elapsed: 00:57, epoch: 104/200, train_loss: 0.00803, val_loss: 0.04051
# Time elapsed: 00:58, epoch: 105/200, train_loss: 0.00804, val_loss: 0.04022
# Time elapsed: 00:59, epoch: 106/200, train_loss: 0.00800, val_loss: 0.04037
# Time elapsed: 00:59, epoch: 107/200, train_loss: 0.00801, val_loss: 0.04013
# Time elapsed: 01:00, epoch: 108/200, train_loss: 0.00800, val_loss: 0.04031
# Time elapsed: 01:01, epoch: 109/200, train_loss: 0.00794, val_loss: 0.04004
# Time elapsed: 01:02, epoch: 110/200, train_loss: 0.00792, val_loss: 0.04015
# Time elapsed: 01:02, epoch: 111/200, train_loss: 0.00791, val_loss: 0.04016
# Time elapsed: 01:03, epoch: 112/200, train_loss: 0.00788, val_loss: 0.04046
# Time elapsed: 01:04, epoch: 113/200, train_loss: 0.00784, val_loss: 0.04031
# Time elapsed: 01:05, epoch: 114/200, train_loss: 0.00785, val_loss: 0.04059
# Time elapsed: 01:05, epoch: 115/200, train_loss: 0.00791, val_loss: 0.04063
# Time elapsed: 01:06, epoch: 116/200, train_loss: 0.00789, val_loss: 0.04043
# Time elapsed: 01:07, epoch: 117/200, train_loss: 0.00785, val_loss: 0.04070
# Time elapsed: 01:08, epoch: 118/200, train_loss: 0.00785, val_loss: 0.04020
# Time elapsed: 01:09, epoch: 119/200, train_loss: 0.00784, val_loss: 0.04104
# Time elapsed: 01:10, epoch: 120/200, train_loss: 0.00789, val_loss: 0.04018
# Time elapsed: 01:11, epoch: 121/200, train_loss: 0.00783, val_loss: 0.04077
# Time elapsed: 01:12, epoch: 122/200, train_loss: 0.00780, val_loss: 0.04042
# Time elapsed: 01:13, epoch: 123/200, train_loss: 0.00778, val_loss: 0.04088
# Time elapsed: 01:14, epoch: 124/200, train_loss: 0.00778, val_loss: 0.04055
# Time elapsed: 01:15, epoch: 125/200, train_loss: 0.00775, val_loss: 0.04062
# Time elapsed: 01:17, epoch: 126/200, train_loss: 0.00776, val_loss: 0.04078
# Time elapsed: 01:18, epoch: 127/200, train_loss: 0.00771, val_loss: 0.04047
# Time elapsed: 01:20, epoch: 128/200, train_loss: 0.00770, val_loss: 0.04046
# Time elapsed: 01:21, epoch: 129/200, train_loss: 0.00773, val_loss: 0.04049
# Time elapsed: 01:22, epoch: 130/200, train_loss: 0.00775, val_loss: 0.04075
# Time elapsed: 01:24, epoch: 131/200, train_loss: 0.00774, val_loss: 0.04057
# Time elapsed: 01:25, epoch: 132/200, train_loss: 0.00771, val_loss: 0.04044
# Time elapsed: 01:27, epoch: 133/200, train_loss: 0.00766, val_loss: 0.04063
# Time elapsed: 01:30, epoch: 134/200, train_loss: 0.00765, val_loss: 0.04054
# Time elapsed: 01:32, epoch: 135/200, train_loss: 0.00766, val_loss: 0.04098
# Time elapsed: 01:35, epoch: 136/200, train_loss: 0.00769, val_loss: 0.04052
# Time elapsed: 01:38, epoch: 137/200, train_loss: 0.00769, val_loss: 0.04112
# Time elapsed: 01:41, epoch: 138/200, train_loss: 0.00767, val_loss: 0.04040
# Time elapsed: 01:44, epoch: 139/200, train_loss: 0.00765, val_loss: 0.04071
# Time elapsed: 01:47, epoch: 140/200, train_loss: 0.00762, val_loss: 0.04103
# Time elapsed: 01:50, epoch: 141/200, train_loss: 0.00764, val_loss: 0.04096
# Time elapsed: 01:53, epoch: 142/200, train_loss: 0.00764, val_loss: 0.04099
# Time elapsed: 01:56, epoch: 143/200, train_loss: 0.00765, val_loss: 0.04064
# Time elapsed: 01:59, epoch: 144/200, train_loss: 0.00760, val_loss: 0.04106
# Time elapsed: 02:03, epoch: 145/200, train_loss: 0.00759, val_loss: 0.04122
# Time elapsed: 02:06, epoch: 146/200, train_loss: 0.00767, val_loss: 0.04066
# Time elapsed: 02:09, epoch: 147/200, train_loss: 0.00761, val_loss: 0.04113
# Time elapsed: 02:12, epoch: 148/200, train_loss: 0.00761, val_loss: 0.04090
# Time elapsed: 02:15, epoch: 149/200, train_loss: 0.00757, val_loss: 0.04080
# Time elapsed: 02:18, epoch: 150/200, train_loss: 0.00753, val_loss: 0.04115
# Time elapsed: 02:21, epoch: 151/200, train_loss: 0.00754, val_loss: 0.04127
# Time elapsed: 02:24, epoch: 152/200, train_loss: 0.00759, val_loss: 0.04074
# Time elapsed: 02:27, epoch: 153/200, train_loss: 0.00754, val_loss: 0.04071
# Time elapsed: 02:30, epoch: 154/200, train_loss: 0.00754, val_loss: 0.04134
# Time elapsed: 02:34, epoch: 155/200, train_loss: 0.00756, val_loss: 0.04086
# Time elapsed: 02:37, epoch: 156/200, train_loss: 0.00756, val_loss: 0.04133
# Time elapsed: 02:40, epoch: 157/200, train_loss: 0.00756, val_loss: 0.04110
# Time elapsed: 02:43, epoch: 158/200, train_loss: 0.00754, val_loss: 0.04097
# Time elapsed: 02:46, epoch: 159/200, train_loss: 0.00749, val_loss: 0.04115
# Time elapsed: 02:49, epoch: 160/200, train_loss: 0.00747, val_loss: 0.04082
# Time elapsed: 02:52, epoch: 161/200, train_loss: 0.00752, val_loss: 0.04126
# Time elapsed: 02:55, epoch: 162/200, train_loss: 0.00748, val_loss: 0.04132
# Time elapsed: 02:58, epoch: 163/200, train_loss: 0.00749, val_loss: 0.04091
# Time elapsed: 03:01, epoch: 164/200, train_loss: 0.00749, val_loss: 0.04121
# Time elapsed: 03:04, epoch: 165/200, train_loss: 0.00747, val_loss: 0.04127
# Time elapsed: 03:07, epoch: 166/200, train_loss: 0.00746, val_loss: 0.04080
# Time elapsed: 03:10, epoch: 167/200, train_loss: 0.00746, val_loss: 0.04106
# Time elapsed: 03:14, epoch: 168/200, train_loss: 0.00742, val_loss: 0.04128
# Time elapsed: 03:17, epoch: 169/200, train_loss: 0.00746, val_loss: 0.04143
# Time elapsed: 03:19, epoch: 170/200, train_loss: 0.00745, val_loss: 0.04149
# Time elapsed: 03:22, epoch: 171/200, train_loss: 0.00747, val_loss: 0.04179
# Time elapsed: 03:25, epoch: 172/200, train_loss: 0.00743, val_loss: 0.04141
# Time elapsed: 03:28, epoch: 173/200, train_loss: 0.00748, val_loss: 0.04142
# Time elapsed: 03:31, epoch: 174/200, train_loss: 0.00742, val_loss: 0.04122
# Time elapsed: 03:34, epoch: 175/200, train_loss: 0.00738, val_loss: 0.04144
# Time elapsed: 03:37, epoch: 176/200, train_loss: 0.00739, val_loss: 0.04148
# Time elapsed: 03:39, epoch: 177/200, train_loss: 0.00739, val_loss: 0.04160
# Time elapsed: 03:42, epoch: 178/200, train_loss: 0.00740, val_loss: 0.04149
# Time elapsed: 03:46, epoch: 179/200, train_loss: 0.00738, val_loss: 0.04117
# Time elapsed: 03:49, epoch: 180/200, train_loss: 0.00743, val_loss: 0.04155
# Time elapsed: 03:53, epoch: 181/200, train_loss: 0.00737, val_loss: 0.04137
# Time elapsed: 03:56, epoch: 182/200, train_loss: 0.00738, val_loss: 0.04144
# Time elapsed: 04:00, epoch: 183/200, train_loss: 0.00739, val_loss: 0.04136
# Time elapsed: 04:03, epoch: 184/200, train_loss: 0.00737, val_loss: 0.04131
# Time elapsed: 04:06, epoch: 185/200, train_loss: 0.00740, val_loss: 0.04104
# Time elapsed: 04:09, epoch: 186/200, train_loss: 0.00739, val_loss: 0.04133
# Time elapsed: 04:12, epoch: 187/200, train_loss: 0.00737, val_loss: 0.04172
# Time elapsed: 04:16, epoch: 188/200, train_loss: 0.00736, val_loss: 0.04133
# Time elapsed: 04:19, epoch: 189/200, train_loss: 0.00735, val_loss: 0.04133
# Time elapsed: 04:22, epoch: 190/200, train_loss: 0.00736, val_loss: 0.04100
# Time elapsed: 04:25, epoch: 191/200, train_loss: 0.00738, val_loss: 0.04101
# Time elapsed: 04:28, epoch: 192/200, train_loss: 0.00735, val_loss: 0.04179
# Time elapsed: 04:31, epoch: 193/200, train_loss: 0.00739, val_loss: 0.04139
# Time elapsed: 04:34, epoch: 194/200, train_loss: 0.00735, val_loss: 0.04113
# Time elapsed: 04:37, epoch: 195/200, train_loss: 0.00733, val_loss: 0.04119
# Time elapsed: 04:40, epoch: 196/200, train_loss: 0.00733, val_loss: 0.04126
# Time elapsed: 04:43, epoch: 197/200, train_loss: 0.00732, val_loss: 0.04153
# Time elapsed: 04:46, epoch: 198/200, train_loss: 0.00735, val_loss: 0.04199
# Time elapsed: 04:49, epoch: 199/200, train_loss: 0.00741, val_loss: 0.04110
# Time elapsed: 04:52, epoch: 200/200, train_loss: 0.00745, val_loss: 0.04176

# %%
MODEL_PATH = r"model/complex_ae.pt"
torch.save({
            'epoch': EPOCHS,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            }, MODEL_PATH)

# %%
import matplotlib.pyplot as plt
import numpy as np

FIGURE_FONT_SIZE = 8
fig = plt.figure()
out = evaluate_image(normal_loader)
for i in range(1, 6):
        original_image, reconstrucet_image, loss, _ = out[i]
        ax1 = fig.add_subplot(2, 5, i)
        ax1.set_title(f"MSE: {loss:2f}", fontsize=FIGURE_FONT_SIZE) 
        plt.imshow(np.array(original_image).reshape(IMG_DIM, IMG_DIM))
        ax2 = fig.add_subplot(2, 5, i+5)
        # ax2.set_title(f"MSE: {loss:2f}", fontsize=FIGURE_FONT_SIZE) 
        plt.imshow(np.array(reconstrucet_image).reshape(IMG_DIM, IMG_DIM))

mean_loss = np.mean([element[2] for element in out])
std_loss = np.std([element[2] for element in out])
print(f"mean loss for normal data: {mean_loss}, std: {std_loss}")

plt.savefig(f"regular_training_normal_reconstruction_MNIST_noise_lvl{'03'}")
plt.show()
plt.close()

fig = plt.figure()
out = evaluate_image(anomaly_loader)
for i in range(1, 6):
        original_image, reconstrucet_image, loss, _ = out[i]
        ax1 = fig.add_subplot(2, 5, i)
        ax1.set_title(f"MSE: {loss:2f}", fontsize=FIGURE_FONT_SIZE) 
        plt.imshow(np.array(original_image).reshape(IMG_DIM, IMG_DIM))
        ax2 = fig.add_subplot(2, 5, i+5)
        # ax2.set_title(f"MSE: {loss:2f}", fontsize=FIGURE_FONT_SIZE) 
        plt.imshow(np.array(reconstrucet_image).reshape(IMG_DIM, IMG_DIM))

mean_loss = np.mean([element[2] for element in out])
std_loss = np.std([element[2] for element in out])

print(f"mean loss for anomaly data: {mean_loss}, std: {std_loss}")

plt.savefig(f"regular_training_anomaly_reconstruction_MNIST_noise_lvl{'03'}")
plt.show()
plt.close()
# Out:
# mean loss for normal data: 0.04248137269867584, std: 0.02228322850571782
# mean loss for anomaly data: 0.12454481437802314, std: 0.016151220857436994
